# %%
import pandas as pd

#データフレーム作成
df = pd.DataFrame({
    '日付':
         ['2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20', '2023-05-21'],
    '社員名': ['山田', '佐藤', '鈴木', '田中', '高橋'],
    '売上': [100, 200, 150, 300, 250],
    '部門': ['メーカー', '代理店', 'メーカー', '商社', '代理店']
})

#平均売上列を作成
df['平均売上'] = df['売上'].mean()
ave = df['売上'].mean()

#業績ランク列を作成する関数を定義
def perfomance(runk):
  result = ''
  if runk >= (ave + 50):
    result = 'A'
  elif runk >= ave:
    result = 'B'
  else:
    result = 'C'
  return result

#業績ランク列を作成し、関数を適用して値を設定（dataフレームからdataフレームに）
df['業績ランク'] = df['売上'].apply(perfomance)

#エクセルファイルを作成
writer = pd.ExcelWriter('業績.xlsx')

#データフレームをエクセルに書き込み
df.to_excel(writer,sheet_name= 'sheet1',index=False)

#閉じる
writer.close()
